# %%
! python -m crossval_domain_adaptation --epochs=20 --lr=1e-4 --reg=0 --seed=1 --batch_size=8 --csv_name=domain_adaptation_adam_fc128_gat128_fc64_lr1eminus4_batch8_epochs20_tanh_no_dropout --theta=1.
# Out:
# Load Train and Test Set
# ...
#  86%|████████▌ | 296/344 [00:02<00:00, 100.54it/s]
# Init Model
# Start Training
# Start Testing
#
# ROC AUC:0.6223343269892226
# Load Train and Test Set
# Init Model
# Start Training
# Start Testing
#
# ROC AUC:0.620441705187468
# Load Train and Test Set
# Init Model
# Start Training
# Start Testing
#
# ROC AUC:0.6835038363171356
# Mean ROC AUC score:0.6420932894979421
# ...
# 100%|██████████| 344/344 [00:03<00:00, 108.84it/s]

# %%
! python -m test_domain_adaptation --epochs=20 --lr=1e-5 --reg=0 --seed=1 --batch_size=8 --file_name=benchmark_domain_adaptation_tanh_fc256_gat128_fc64_fc1_batch8_lr1eminus5_epochs24_tanh_no_dropout --theta=1.
# Out:
# Load Train and Test Set
# ...
#  74%|███████▍  | 254/344 [00:03<00:01, 79.96it/s]
# Init Model
# Start Training
# Start Testing
# ...
# 100%|██████████| 344/344 [00:04<00:00, 74.29it/s]
#
# ...
# 100%|██████████| 149/149 [00:02<00:00, 59.66it/s]
