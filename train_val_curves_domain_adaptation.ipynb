# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_mean_roc_auc(model,title=''):
    df = model
    df['mean_roc_auc'] = (df['val_roc_auc_C_1']+df['val_roc_auc_C_2']+df['val_roc_auc_C_5'])/3
    df[['mean_roc_auc','val_roc_auc_C_1','val_roc_auc_C_2','val_roc_auc_C_5']].plot()
    print(f"Maximal mean ROC AUC = {max((model['val_roc_auc_C_1']+model['val_roc_auc_C_2']+model['val_roc_auc_C_5'])/3)}")

def plot_val_loss(model,title=''):
    df = model
    df[['val_loss_C_1','val_loss_C_2','val_loss_C_5']].plot()

def plot_losses(model,val_center):
  model[['val_loss_'+val_center,'train_loss_'+val_center]].plot()

# %%
model1 = pd.read_csv("domain_adaptation_v2_fc256_gat256_fc128_fc64_fc1_batch8_lr1eminus5_epochs40_tanh_no_dropout.csv")
model2 = pd.read_csv("domain_adaptation_fc128_gat128_lr1eminus4__batch8_epochs20_tanh_no_dropout.csv")
model3 = pd.read_csv("domain_adaptation_fc128_gat128_lr1eminus5__batch8_epochs20_tanh_no_dropout.csv")
model4 = pd.read_csv("domain_adaptation_fc256_att128_fc64_lr1eminus5_batch8_epochs20_tanh_no_dropout.csv")
model5 = pd.read_csv("domain_adaptation_fc256_gat128_fc64_lr1eminus5_batch8_epochs20_tanh_no_dropout.csv")
model6 = pd.read_csv("domain_adaptation_fc256_gat128_fc64_lr5eminus5_batch8_epochs20_tanh_no_dropout.csv")
model7 = pd.read_csv("domain_adaptation_fc256_gat128_fc64_lr1eminus4_batch8_epochs20_tanh_no_dropout.csv")
model8 = pd.read_csv("domain_adaptation_fc256_gat128_fc64_lr1eminus5_batch4_epochs20_tanh_no_dropout.csv")
model9 = pd.read_csv("domain_adaptation_sgd_fc256_gat128_fc64_lr1eminus3_batch4_epochs20_tanh_no_dropout.csv")
model10 = pd.read_csv("domain_adaptation_adam_fc128_gat128_lr1eminus5_batch8_epochs20_tanh_no_dropout.csv")
model11 = pd.read_csv("domain_adaptation_adam_fc128_gat128_lr1eminus3_batch16_epochs20_tanh_no_dropout.csv")
model12 = pd.read_csv("domain_adaptation_sgd_fc128_gat128_lr1eminus3_batch8_epochs20_tanh_no_dropout.csv")
model13 = pd.read_csv("domain_adaptation_adam_fc128_gat128_lr1eminus4_batch8_epochs20_tanh_no_dropout.csv")
model14 = pd.read_csv("domain_adaptation_adam_fc128_gat128_fc64_lr1eminus5_batch8_epochs20_tanh_no_dropout.csv")
model15 = pd.read_csv("domain_adaptation_adam_fc128_gat128_fc64_lr1eminus4_batch8_epochs20_tanh_no_dropout.csv")

# %%
plot_mean_roc_auc(model14)
# Out:
# Maximal mean ROC AUC = 0.663317946216607

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1f8a688cae5d> in <module>
# ----> 1 model
#
# NameError: name 'model' is not defined
